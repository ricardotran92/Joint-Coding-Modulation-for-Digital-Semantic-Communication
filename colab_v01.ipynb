# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = "/content/drive/MyDrive/Colab Notebooks/JCMDSC_adversarial"
# %cd $path
os.getcwd()
# Out:
# /content/drive/MyDrive/Colab Notebooks/JCMDSC_adversarial
# '/content/drive/MyDrive/Colab Notebooks/JCMDSC_adversarial'

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib<4,>=3.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pandas<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: scikit_learn<2,>=1.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: scipy<2,>=1.13 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: scikit-image<1,>=0.22 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.25.2)
# Requirement already satisfied: torch>=2.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.19 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.25.0+cu128)
# Requirement already satisfied: tqdm>=4.65 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn<2,>=1.4->-r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn<2,>=1.4->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1,>=0.22->-r requirements.txt (line 6)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1,>=0.22->-r requirements.txt (line 6)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1,>=0.22->-r requirements.txt (line 6)) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1,>=0.22->-r requirements.txt (line 6)) (0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.4->-r requirements.txt (line 7)) (1.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4,>=3.8->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4->-r requirements.txt (line 7)) (3.0.3)

# %%
# !python main.py --mode 'train' --mod_method '64qam' --pretrain_analog 0
# Out:
# Loading the pretrained analog network...
# Successfully load the pretrained analog model!
# Training with the modulation scheme 64qam.
# 100% 1563/1563 [01:21<00:00, 19.14it/s]
# 100% 313/313 [00:16<00:00, 18.45it/s]
# epoch: 0, loss: 19.869672, acc: 0.850, mse: 0.015745, psnr: 18.546, ssim: 0.321, lr: 0.000051
# train acc: 0.800
# train psnr: 17.182
# =>Saving checkpoint

# %%
# !python main.py --mode 'test' --mod_method '64qam' --pretrain_analog 0 --load_checkpoint 1
# Out:
# Start Testing.
# 100% 313/313 [00:22<00:00, 14.17it/s]
# acc: 0.873, mse: 0.004263, psnr: 24.259, ssmi: 0.720
